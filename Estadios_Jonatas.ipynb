# %% [markdown]
# <a href="https://colab.research.google.com/github/JonatasGdeC/Aulas-Banco_Nao_Relacional/blob/main/Estadios_Jonatas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação das Bibliotecas

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 11.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Dataset contendo dados dos estádios

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %% [markdown]
# Conversão em DATAFRAME PANDA

# %%
estadio_df = pd.read_csv(dataset)

# %% [markdown]
# Visualizando os 5 primeiros registros do DataFrame

# %%
# Load the necessary library.
import pandas as pd

# Define the dataset URL.
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# Read the CSV file into a Pandas DataFrame, ensuring consistent variable naming.
estadios_df = pd.read_csv(dataset)  # Changed variable name to 'estadios_df'

# Display the first 5 rows of the DataFrame.
estadios_df.head(5)  # Use the correct variable name 'estadios_df'
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %% [markdown]
# Convertendo o DataFrame em um dicionário (arquivo parecido com um JSON)

# %%
dicionario_estadios = estadios_df.to_dict(orient='records')

# %% [markdown]
# visualizando o dicionario...

# %%
dicionario_estadios
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
# ...

# %%
cliente = MongoClient("mongodb+srv://jonatas07022003:qcx7SldQlcGu2Wbi@cluster0fatec.gxpjv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0Fatec")

# %%
db = cliente.get_database('futebol')

# %%
db.estadios.insert_many(dicionario_estadios)
# Out:
# InsertManyResult([ObjectId('6719ac2087bf1a6b1b655cbe'), ObjectId('6719ac2087bf1a6b1b655cbf'), ObjectId('6719ac2087bf1a6b1b655cc0'), ObjectId('6719ac2087bf1a6b1b655cc1'), ObjectId('6719ac2087bf1a6b1b655cc2'), ObjectId('6719ac2087bf1a6b1b655cc3'), ObjectId('6719ac2087bf1a6b1b655cc4'), ObjectId('6719ac2087bf1a6b1b655cc5'), ObjectId('6719ac2087bf1a6b1b655cc6'), ObjectId('6719ac2087bf1a6b1b655cc7'), ObjectId('6719ac2087bf1a6b1b655cc8'), ObjectId('6719ac2087bf1a6b1b655cc9'), ObjectId('6719ac2087bf1a6b1b655cca'), ObjectId('6719ac2087bf1a6b1b655ccb'), ObjectId('6719ac2087bf1a6b1b655ccc'), ObjectId('6719ac2087bf1a6b1b655ccd'), ObjectId('6719ac2087bf1a6b1b655cce'), ObjectId('6719ac2087bf1a6b1b655ccf'), ObjectId('6719ac2087bf1a6b1b655cd0'), ObjectId('6719ac2087bf1a6b1b655cd1')], acknowledged=True)

# %%
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['cluster0fatec-shard-00-00.gxpjv.mongodb.net:27017', 'cluster0fatec-shard-00-01.gxpjv.mongodb.net:27017', 'cluster0fatec-shard-00-02.gxpjv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0Fatec', authsource='admin', replicaset='atlas-fxkfa6-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('6719ac2087bf1a6b1b655cbe'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('6719ac2087bf1a6b1b655cbf'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('6719ac2087bf1a6b1b655cc0'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('6719ac2087bf1a6b1b655cc1'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('6719ac2087bf1a6b1b655cc2'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('6719ac2087bf1a6b1b655cc3'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6719ac2087bf1a6b1b655cc4'),
# ...

# %%
#definindo o centro do brasil
center_lat = -12.24007
center_lon = -51.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           6719ac2087bf1a6b1b655cbe
# nome                          Maracanã
# capacidade                       78838
# latitude                     -22.90981
# longitude                    -43.23391
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width=800, height=600)

# %%
qtde = len(df_convertido)

# %%
for i in range(qtde):
    lat = df_convertido.iloc[i]['latitude']
    lon = df_convertido.iloc[i]['longitude']
    description = 'Estadio:' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade:' + str(df_convertido.iloc[i]['capacidade'])
    folium.Marker([lat, lon],
                  popup=description, icon=folium.Icon(color='green')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
